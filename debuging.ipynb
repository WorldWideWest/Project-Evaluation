# %%
from cashFlow import *
from periodChecking import *
from evaluatingMethods import *

# %%
project_A = ['Project 1', 15000, 1000, 2000, 3000, 4000, 5000, 6000]
project_B = ['Project 2', 15000, 3500, 3500, 3500, 3500, 3500, 3500]
project_C = ['Project 3', 15000, 6000, 5000, 4000, 3000, 2000, 1000]

projects = [project_A, project_B, project_C]

# %%
cashFlow = NCF(projects)

dataFrame = cashFlow.Table(False)
evaulation = Methods(dataFrame)
evaulation.InternalReturnRate()
# Out:
# CVCF - Current Value of the Cash flow
# NPV - Net Present Value
#    Discount Rate  Project 1 CVCF  Project 2 CVCF  Project 3 CVCF  \
# 0              0        21000.00        21000.00        21000.00
# 1              5        17043.69        17764.92        18486.16
# 2             10        14039.43        15243.41        16447.39
# 3             15        11721.26        13245.69        14770.12
# 4             20         9906.12        11639.29        13372.45
# 5             25         8465.66        10329.98        12194.30
# 6             30         7308.37         9249.61        11190.85
# 7             35         6367.97         8348.05        10328.12
# 8             40         5595.76         7587.91         9580.06
# 9             45         4955.46         6940.93         8926.39
#
#    Project 1 NPV  Project 2 NPV  Project 3 NPV
# 0        6000.00        6000.00        6000.00
# 1        2043.69        2764.92        3486.16
# 2        -960.57         243.41        1447.39
# 3       -3278.74       -1754.31        -229.88
# 4       -5093.88       -3360.71       -1627.55
# 5       -6534.34       -4670.02       -2805.70
# 6       -7691.63       -5750.39       -3809.15
# 7       -8632.03       -6651.95       -4671.88
# 8       -9404.24       -7412.09       -5419.94
# 9      -10044.54       -8059.07       -6073.61
